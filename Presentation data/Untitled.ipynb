# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tips=pd.read_csv('all_stocks_2006-01-01_to_2018-01-01.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-400e0dd04265> in <module>()
# ----> 1 tips=pd.read_csv('all_stocks_2006-01-01_to_2018-01-01.csv')
#
# ...

# %%
tips
# Out:
#                                      Agency State  Months  Population  \
# 0                       Abilene Police Dept    TX      12      119886
# 1                    Akron City Police Dept    OH      12      198390
# 2                    Alexandria Police Dept    VA      12      145892
# 3                Allentown City Police Dept    PA      12      119334
# 4                      Amarillo Police Dept    TX      12      196576
# 5                  Amherst Town Police Dept    NY      12      117591
# 6                     Ann Arbor Police Dept    MI      12      115008
# 7                       Antioch Police Dept    CA      12      105009
# 8                        Arvada Police Dept    CO      12      109029
# 9    Athens-Clarke County Police Department    GA      12      117457
# 10                       Aurora Police Dept    IL      12      199765
# 11                  Baton Rouge Police Dept    LA      12      231500
# ...

# %%
tips.describe()
# Out:
#        Months     Population  Violent_crime_total  Murder_and_Manslaughter  \
# count   213.0     213.000000           213.000000               213.000000
# mean     12.0  149576.061033           745.070423                 8.741784
# std       0.0   43228.795549           588.956072                11.518402
# min      12.0  100040.000000             0.000000                 0.000000
# 25%      12.0  112247.000000           310.000000                 2.000000
# 50%      12.0  137356.000000           564.000000                 5.000000
# 75%      12.0  181591.000000          1027.000000                12.000000
# max      12.0  249830.000000          3237.000000                67.000000
#
#        Forcible_rape      Robbery  Aggravated_assault  Property_crime_total  \
# count     213.000000   213.000000          213.000000            213.000000
# mean       47.821596   241.309859          447.953052           5544.826291
# ...

# %%
sns.pairplot(tips)
